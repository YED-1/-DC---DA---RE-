# %%
# Visualización de los datos para la tabla df_limpio

#Personajes con más apariciones en videojuegos

import matplotlib.pyplot as plt
import pandas as pd

ruta_procesada = '..\data\processed\df_limpio.csv'
df = pd.read_csv(ruta_procesada)
df # Checado de la tabla

top_personajes = df['character_name'].value_counts().head(10) #Variable para sacar el numero de apariciones en un rango de 10
top_personajes = top_personajes[::-1] #Esto hace que nuestra tabla se invierta y pueda salir el personaje de más apariciones al que menos tiene

plt.barh(y=top_personajes.index, width=top_personajes.values) #Método para realizar una grafica de barras acostada
plt.ylabel('Nombre del personaje') 
plt.xlabel('Apariciones')
plt.title('Top personajes con más apariciones')

plt.show()

# %%
# Visualización de los datos para la tabla df_limpio

#Personajes con más escenas

import matplotlib.pyplot as plt
import pandas as pd

ruta_procesada = '..\data\processed\df_limpio_in.csv'
df = pd.read_csv(ruta_procesada)
df # Checado de la tabla

top_personajes = df['scene_id'].value_counts().head(10) #Variable para sacar el numero de apariciones en un rango de 10
top_personajes = top_personajes[::-1] #Esto hace que nuestra tabla se invierta y pueda salir el personaje de más apariciones al que menos tiene

plt.barh(y=top_personajes.index, width=top_personajes.values) #Método para realizar una grafica de barras acostada
plt.ylabel('ID de la escena') 
plt.xlabel('Número de interacciones')
plt.title('Top Escenas con más interacciones')

plt.show()

# %%
# Visualización de datos con tabla df_limpio_in

# Personajes con más interacciones

import matplotlib.pyplot as plt
import pandas as pd

ruta_procesada = '..\data\processed\df_limpio_in.csv'
df = pd.read_csv(ruta_procesada)
df # Checado de la tabla

top_personajes = df['name'].value_counts().head(10) #Variable para sacar el numero de apariciones en un rango de 10
top_personajes = top_personajes[::-1] #Esto hace que nuestra tabla se invierta y pueda salir el personaje de más apariciones al que menos tiene

plt.barh(y=top_personajes.index, width=top_personajes.values) #Método para realizar una grafica de barras acostada
plt.ylabel('Nombre del personaje') 
plt.xlabel('Interacciones')
plt.title('Top personajes con más interacciones en los juegos')

plt.show()

# %%
# Visualización de los datos para la tabla df_limpio_in

# Juego con más interacciónes

# Código similar al de personajes con más apariciones

import matplotlib.pyplot as plt
import pandas as pd

ruta_procesada = '..\data\processed\df_limpio_in.csv'
df = pd.read_csv(ruta_procesada)
df # Checado de la tabla

rescenes = df['game_id'].value_counts().head(10)
rescenes = rescenes[::-1] #Esto hace que nuestra tabla se invierta y pueda salir el personaje de más apariciones al que menos tiene

plt.barh(y=rescenes.index, width=rescenes.values) #Método para realizar una grafica de barras acostada
plt.ylabel('ID_juego') 
plt.xlabel('Número de interacciones')
plt.title('Top juegos con más interacciones')

plt.show()

# %%
# Visualización de los datos para la tabla df_limpio_in

# Juego con más escenas

# Código similar al de personajes con más apariciones

import matplotlib.pyplot as plt
import pandas as pd

ruta_procesada = '..\data\processed\df_limpio_in.csv'
df = pd.read_csv(ruta_procesada)
df # Checado de la tabla

rescenes = df['game_id'].value_counts().head(10)
rescenes = rescenes[::-1] #Esto hace que nuestra tabla se invierta y pueda salir el personaje de más apariciones al que menos tiene

plt.barh(y=rescenes.index, width=rescenes.values) #Método para realizar una grafica de barras acostada
plt.ylabel('ID_juego') 
plt.xlabel('Número de interacciones')
plt.title('Top juegos con más interacciones')

plt.show()

# %%
# Visualización de los datos para la tabla df_limpio

#Cronología de los juegos de lanzamiento de los juegos

import matplotlib.pyplot as plt
import pandas as pd

ruta_procesada = '..\data\processed\df_limpio.csv'
df = pd.read_csv(ruta_procesada)
df # Checado de la tabla

cronologia = df[['game_title', 'year']].drop_duplicates().sort_values('year')

plt.scatter(x=cronologia['year'], y=cronologia['game_title'])

plt.title('Cronología de Resident Evil')
plt.xlabel('Año de lanzamiento')
plt.ylabel('Titulo del juego')

plt.show()

# %%
# Visualización de los datos para la tabla df_limpio

# Juego con más apariciones de personajes

# Código similar al de personajes con más apariciones

import matplotlib.pyplot as plt
import pandas as pd

ruta_procesada = '..\data\processed\df_limpio.csv'
df = pd.read_csv(ruta_procesada)
df # Checado de la tabla

juegopari = df['game_title'].value_counts() 
juegopari = juegopari[::-1] #Esto hace que nuestra tabla se invierta y pueda salir el personaje de más apariciones al que menos tiene

plt.barh(y=juegopari.index, width=juegopari.values) #Método para realizar una grafica de barras acostada
plt.ylabel('Nombre del Juego') 
plt.xlabel('Numero de personajes')
plt.title('Top Juegos con más personajes')

plt.show()
